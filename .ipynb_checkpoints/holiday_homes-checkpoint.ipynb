# %% [markdown]
# ## AIM of the project
#
# * To provide a list of cottages in France from a popular website in **CSV** format which includes:-
#     * Name of the cottage
#     * The price,
#     * no. of bedroom
#     * sleeps
#     * Rating of the cottages.
# * website:- https://www.holidayfrancedirect.co.uk/cottages-holidays/index.htm
# ### Work Flow
#     * Extract name, price, bedrooms, sleeps and rating of all the cottage from single webpage.
#     * Then we will Paginate through all of the webpages and extract all the required information
#     from each page.
#     * Ten we will save the data in csv format by using pandas library.

# %%
# importing the libraries

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Extracting information from a single webpage

# %%
# url of the page
url = 'https://www.holidayfrancedirect.co.uk/cottages-holidays/index.htm'

# %%
# get the webpage by using request.
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Cottages in France - Holiday France Direct</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="no" name="msapplication-tap-highlight">
# <meta content="AIzaSyDO37eCoBchoUQceSL2r_7h9q3xF_sjsh8" name="gm-js-api">
# <link href="/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
print(soup.title)
# Out:
# <title>Cottages in France - Holiday France Direct</title>

# %%
content = soup.find_all('div', class_='property-grid-item')

# %%
content
# Out:
# [<div class="property-grid-item" data-id="1" data-image-id="99073" data-image-ids="99073,134938,134936,99066,130415,134934,134933,130416,134937,134935,77078,77079,99068,77080,77084,77085,77083,77086">
#  <article class="media-listing layout-stacked">
#  <div class="col-media">
#  <figure class="property-bg-img" style="background-image: url('https://image-cdn.holidayfrancedirect.co.uk/cspreview/99073.jpg');">
#  <a class="image-link" href="https://www.holidayfrancedirect.co.uk/holiday-rentals/AD005990/index.htm">
#  <img alt="1 bedroom gite to let in rural Dordogne" class="img-scaffold" src="/images/4-by-3-scaffold.gif"/>
#  </a>
#  <div class="slide-pager">
#  <span class="prev-slide" data-action="prevImage"></span>
#  <span class="next-slide" data-action="nextImage"></span>
#  </div>
#  <a class="shortlist" data-property-id="16943" data-toggle="shortlist" data-url="/shortlist">
# ...

# %%
for property in content:
    print(property.find('h2').text)
    print(property.find('p',class_='property-spec').text)
    print(property.find('div', class_='property-pricing').text)
# Out:
# 1 bedroom gite to let in rural Dordogne - AD005990
# Bedrooms 1, Sleeps 2
# £350 to £756 pw
# Charming couples gite to let in Vienne - PV006319
# Bedrooms 1, Sleeps 2, Ratings 1 10/10
# £400 pw
# Holiday let for 2 in rural Mayenne - LM004798
# Bedrooms 1, Sleeps 2, Ratings 11 9.6/10
# £320 pw
# Holiday gite in Brittany, heated shared pool - BI003636_A
# Bedrooms 1, Sleeps 2, Ratings 4 9.9/10
# £320 to £435 pw
# Beautiful gite in rural Calvados, Normandy - NC003499
# Bedrooms 1, Sleeps 2, Ratings 4 10/10
# £495 to £720 pw
# Luxury gite with 3 fishing lakes in Mayenne - LM004583
# Bedrooms 3, Sleeps 6, Ratings 10 10/10
# £839 to £1289 pw
# Cottage to let in Brittany - BM004606
# Bedrooms 2, Sleeps 4, Ratings 1 8.2/10
# £320 to £395 pw
# Holiday gite in Ploerdut, Brittany - BM005945
# Bedrooms 3, Sleeps 6, Ratings 5 10/10
# £525 to £630 pw
# Holiday cottage in Brittany, sea 35 mins - BN002685
# Bedrooms 3, Sleeps 6, Ratings 2 9.8/10
# £275 to £325 pw
# ...

# %%
for property in content:
    name = property.find('h2').text
    spec = property.find('p',class_='property-spec').text
    price = property.find('div', class_='property-pricing').text
    print(name, spec, price)
# Out:
# 1 bedroom gite to let in rural Dordogne - AD005990 Bedrooms 1, Sleeps 2 £350 to £756 pw
# Charming couples gite to let in Vienne - PV006319 Bedrooms 1, Sleeps 2, Ratings 1 10/10 £400 pw
# Holiday let for 2 in rural Mayenne - LM004798 Bedrooms 1, Sleeps 2, Ratings 11 9.6/10 £320 pw
# Holiday gite in Brittany, heated shared pool - BI003636_A Bedrooms 1, Sleeps 2, Ratings 4 9.9/10 £320 to £435 pw
# Beautiful gite in rural Calvados, Normandy - NC003499 Bedrooms 1, Sleeps 2, Ratings 4 10/10 £495 to £720 pw
# Luxury gite with 3 fishing lakes in Mayenne - LM004583 Bedrooms 3, Sleeps 6, Ratings 10 10/10 £839 to £1289 pw
# Cottage to let in Brittany - BM004606 Bedrooms 2, Sleeps 4, Ratings 1 8.2/10 £320 to £395 pw
# Holiday gite in Ploerdut, Brittany - BM005945 Bedrooms 3, Sleeps 6, Ratings 5 10/10 £525 to £630 pw
# Holiday cottage in Brittany, sea 35 mins - BN002685 Bedrooms 3, Sleeps 6, Ratings 2 9.8/10 £275 to £325 pw
# ...

# %% [markdown]
# ### Adding all these information in a dictionary

# %%
for property in content:
    name = property.find('h2').text
    spec = property.find('p',class_='property-spec').text
    price = property.find('div', class_='property-pricing').text
    
    property_info ={
        'name': name,
        'spec': spec,
        'price' : price
    }
    print(property_info)
# Out:
# {'name': '1 bedroom gite to let in rural Dordogne - AD005990', 'spec': 'Bedrooms 1, Sleeps 2', 'price': '£350 to £756 pw'}
# {'name': 'Charming couples gite to let in Vienne - PV006319', 'spec': 'Bedrooms 1, Sleeps 2, Ratings 1 10/10', 'price': '£400 pw'}
# {'name': 'Holiday let for 2 in rural Mayenne - LM004798', 'spec': 'Bedrooms 1, Sleeps 2, Ratings 11 9.6/10', 'price': '£320 pw'}
# {'name': 'Holiday gite in Brittany, heated shared pool - BI003636_A', 'spec': 'Bedrooms 1, Sleeps 2, Ratings 4 9.9/10', 'price': '£320 to £435 pw'}
# {'name': 'Beautiful gite in rural Calvados, Normandy - NC003499', 'spec': 'Bedrooms 1, Sleeps 2, Ratings 4 10/10', 'price': '£495 to £720 pw'}
# {'name': 'Luxury gite with 3 fishing lakes in Mayenne - LM004583', 'spec': 'Bedrooms 3, Sleeps 6, Ratings 10 10/10', 'price': '£839 to £1289 pw'}
# {'name': 'Cottage to let in Brittany - BM004606', 'spec': 'Bedrooms 2, Sleeps 4, Ratings 1 8.2/10', 'price': '£320 to £395 pw'}
# ...

# %%
holiday_homes = []
for property in content:
    name = property.find('h2').text
    spec = property.find('p',class_='property-spec').text
    price = property.find('div', class_='property-pricing').text
    
    property_info ={
        'name': name,
        'spec': spec,
        'price' : price
    }
    holiday_homes.append(property_info)

# %%
print(holiday_homes)
# Out:
# [{'name': '1 bedroom gite to let in rural Dordogne - AD005990', 'spec': 'Bedrooms 1, Sleeps 2', 'price': '£350 to £756 pw'}, {'name': 'Charming couples gite to let in Vienne - PV006319', 'spec': 'Bedrooms 1, Sleeps 2, Ratings 1 10/10', 'price': '£400 pw'}, {'name': 'Holiday let for 2 in rural Mayenne - LM004798', 'spec': 'Bedrooms 1, Sleeps 2, Ratings 11 9.6/10', 'price': '£320 pw'}, {'name': 'Holiday gite in Brittany, heated shared pool - BI003636_A', 'spec': 'Bedrooms 1, Sleeps 2, Ratings 4 9.9/10', 'price': '£320 to £435 pw'}, {'name': 'Beautiful gite in rural Calvados, Normandy - NC003499', 'spec': 'Bedrooms 1, Sleeps 2, Ratings 4 10/10', 'price': '£495 to £720 pw'}, {'name': 'Luxury gite with 3 fishing lakes in Mayenne - LM004583', 'spec': 'Bedrooms 3, Sleeps 6, Ratings 10 10/10', 'price': '£839 to £1289 pw'}, {'name': 'Cottage to let in Brittany - BM004606', 'spec': 'Bedrooms 2, Sleeps 4, Ratings 1 8.2/10', 'price': '£320 to £395 pw'}, {'name': 'Holiday gite in Ploerdut, Britta
# ...

# %% [markdown]
# # Pagination

# %%
lets say we 10 pages and we want to extract information from all ten page 
* we iterate through all these pages through what we call

# %%
holiday_homes = []                              # emply list for storing list of dictionary 

for page in range(1,11):
    url = f'https://www.holidayfrancedirect.co.uk/cottages-holidays/index.htm?board=sc&d=France&people=2&prop_type%5B0%5D=cottagegite&page=str({page})'
    
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    content = soup.find_all('div', class_='property-grid-item')
    
    for property in content:
        name = property.find('h2').text
        spec = property.find('p',class_='property-spec').text
        price = property.find('div', class_='property-pricing').text
    
        property_info = {
            'name': name,
            'spec': spec,
            'price': price
        }
        holiday_homes.append(property_info)
    print(len(holiday_homes))
# Out:
# 90
# 180
# 270
# 360
# 450
# 540
# 630
# 720
# 810
# 900

# %%
print(holiday_homes)
# Out:
# [{'name': '3 Lovely holiday cottages 1 hr from Cherbourg - NM002654_A', 'spec': 'Bedrooms 4, Sleeps 8, Ratings 1 10/10', 'price': '£435 to £795 pw'}, {'name': 'Holiday let in Montferrat Provence - CV000524_A', 'spec': 'Bedrooms 3, Sleeps 7, Ratings 1 9.3/10', 'price': '£225 to £400 pw'}, {'name': 'Beautiful Perigordian house to let, Aquitaine - AD007472', 'spec': 'Bedrooms 3, Sleeps 6', 'price': '£600 to £995 pw'}, {'name': 'Holiday let 4km from the Vendée coast - LV004385', 'spec': 'Bedrooms 2, Sleeps 5, Ratings 10 9.6/10', 'price': '£345 to £545 pw'}, {'name': 'Holiday cottage, shared pool in Brittany - BN002739_A', 'spec': 'Bedrooms 5, Sleeps 14, Ratings 4 9.7/10', 'price': '£500 to £1000 pw'}, {'name': 'Holiday cottage for rental in Brittany - BI003263', 'spec': 'Bedrooms 2, Sleeps 4, Ratings 4 9.1/10', 'price': '£465 to £595 pw'}, {'name': 'Holiday rental gite nr Bricquebec Manche - NM002658_A', 'spec': 'Bedrooms 3, Sleeps 7, Ratings 1 10/10', 'price': '£750 to £895 pw'}, {'name
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(holiday_homes)

# %%
df.head()
# Out:
#                                                 name  \
# 0  3 Lovely holiday cottages 1 hr from Cherbourg ...
# 1    Holiday let in Montferrat Provence - CV000524_A
# 2  Beautiful Perigordian house to let, Aquitaine ...
# 3   Holiday let 4km from the Vendée coast - LV004385
# 4  Holiday cottage, shared pool in Brittany - BN0...
#
#                                       spec             price
# 0    Bedrooms 4, Sleeps 8, Ratings 1 10/10   £435 to £795 pw
# 1   Bedrooms 3, Sleeps 7, Ratings 1 9.3/10   £225 to £400 pw
# 2                     Bedrooms 3, Sleeps 6   £600 to £995 pw
# 3  Bedrooms 2, Sleeps 5, Ratings 10 9.6/10   £345 to £545 pw
# 4  Bedrooms 5, Sleeps 14, Ratings 4 9.7/10  £500 to £1000 pw

# %%
df.to_csv('holiday_homes.csv')
